# %% [markdown]
# # Import necessary libraries

# %%
# Import pandas library for data manipulation and analysis
import pandas as pd
# Import numpy for numerical operations
import numpy as np
# Import regular expression module for text pattern matching
import re
# Import BeautifulSoup for parsing HTML and XML documents
from bs4 import BeautifulSoup
# Import warnings module to manage warning messages
import warnings
# Import requests library for making HTTP requests
import requests
# Suppress warning messages to keep output clean
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Sending an HTTP GET request to Jumia Nigeria's Apple mobile phones page
# ### And retrieve the HTML content as text for further processing

# %%
# Send an HTTP GET request to Jumia Nigeria's Apple mobile phones page
# and retrieve the HTML content as text for further processing
source = requests.get('https://www.jumia.com.ng/mobile-phones/apple/#catalog-listing').text

# %% [markdown]
# ### Creating a BeautifulSoup object from the HTML source using the lxml parser

# %%
# Create a BeautifulSoup object from the HTML source
# using the 'lxml' parser for efficient HTML parsing
soup = BeautifulSoup(source, 'lxml')

# %% [markdown]
# ### Finding the first 'article' HTML element with class attributes "prd _fb col c-prd"

# %%
# Find the article element with class attributes "prd _fb col c-prd"
# This targets the product container on a webpage
Article = soup.find('article', class_="prd _fb col c-prd")

# %% [markdown]
# ### printing the HTML structure of the 'Article' object in a more readable format

# %%
# This line is commented out, but would print the HTML structure of the 'Article' element
# in a more readable format using BeautifulSoup's prettify() method
#print(Article.prettify())

# %% [markdown]
# ### Extract the phone info from the article by finding the h3 element with class "name"

# %%
# Extract the phone name/info from the article by finding the h3 element with class "name"
# and get its text content with whitespace stripped
phone_info = Article.find('h3', class_="name").get_text(strip=True)
phone_info  # Display the extracted phone information
# Out:
# 'Apple IPhone 14 Pro Max 6.7" (256GB ROM + 6GB RAM) Nano Sim-Purple'

# %% [markdown]
# ### Extract the price text from the HTML element with class "prc"

# %%
# Extract the price text from the HTML element with class "prc"
# Remove spaces and strip whitespace characters from the extracted text
phone_price = Article.find('div', class_="prc").get_text().replace(' ', '').strip()
phone_price  # Return the cleaned price text
# Out:
# '₦1,400,000'

# %% [markdown]
# ### Finding the first anchor tag with an href attribute that starts with '/apple-' and Combine it with base url

# %%
# Define the base URL for Jumia Nigeria
base_link = "https://www.jumia.com.ng"

# Find the first anchor tag with an href attribute that starts with '/apple-'
link = Article.find('a', href=lambda x: x and x.startswith('/apple-'))

# Combine the base URL with the relative path to create a complete URL
full_link = base_link + link['href']

# Print the complete URL
print(full_link)
# Out:
# https://www.jumia.com.ng/apple-iphone-14-pro-max-6.7-256gb-rom-6gb-ram-nano-sim-purple-321406095.html

# %% [markdown]
# ### Looping through pages 1 to 16 of search results to get all the phone information

# %%
# Initialize empty list to store phone data
Phone= []

# Loop through pages 1 to 16 of search results
for page in range(1, 17):
    # Make HTTP request to Jumia website for each page of iPhone search results
    source = requests.get(f"https://www.jumia.com.ng/catalog/?q=iphone&page={page}").text
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(source, 'lxml')

    # Find all product articles on the page
    Articles = soup.find_all('article', class_="prd _fb col c-prd")
    # Print progress information
    print(f"Scraping page {page}... found {len(Articles)} items")

    # Loop through each product article
    for Article in Articles:
        # Extract the phone name, removing extra whitespace
        name = Article.find('h3', class_="name").get_text(strip=True)
        # Extract the price, removing spaces and extra whitespace
        price = Article.find('div', class_="prc").get_text().replace(' ', '').strip()

        # Add the extracted data as a dictionary to the Phone list
        Phone.append({
            'Phone_info': name,
            'Phone_Price': price
        })
# Out:
# Scraping page 1... found 40 items
# Scraping page 2... found 40 items
# Scraping page 3... found 40 items
# Scraping page 4... found 40 items
# Scraping page 5... found 40 items
# Scraping page 6... found 40 items
# Scraping page 7... found 40 items
# Scraping page 8... found 40 items
# Scraping page 9... found 40 items
# Scraping page 10... found 40 items
# Scraping page 11... found 40 items
# Scraping page 12... found 40 items
# Scraping page 13... found 40 items
# Scraping page 14... found 40 items
# Scraping page 15... found 40 items
# Scraping page 16... found 40 items

# %% [markdown]
# ### Printing the length of the Phone scraped

# %%
# Print the length of the Phone variable 
#print(len(Phone))

# %% [markdown]
# ### Creating a DataFrame from the 'Phone' data structure

# %%
# This converts the data into a tabular format for easier manipulation and analysis
#df = pd.DataFrame(Phone)

# %% [markdown]
# ### Saving the DataFrame 'df' to a CSV file

# %%
# Save the DataFrame 'df' to a CSV file named 'jumia_iphones.csv' without including the index column
#df.to_csv("jumia_iphones.csv", index=False)

# %% [markdown]
# ### Reading the saved csv file into a DataFrame

# %%
# Read the iPhone data from the CSV file 'jumia_iphones.csv' into a pandas DataFrame
DataFrame = pd.read_csv("jumia_iphones.csv")

# %% [markdown]
# ### Displaying the first 5 rows

# %%
# Display the first 5 rows of the DataFrame
# For quick inspection of  the data structure and content
DataFrame.head(5)
# Out:
#                                           Phone_info Phone_Price
# 0  Apple IPhone 11 6.1-Inch Liquid Retina LCD (4G...    ₦500,000
# 1  Apple IPhone 12 Pro Max - 6.7-Inch - 128GB ROM...    ₦690,000
# 2     Apple IPhone 16 - 8GB-256GB - 5G - Ultramarine  ₦1,899,000
# 3  PHILLY 50W Iphone Type-c To Lighting  Fast  Ch...      ₦3,912
# 4  IPhone 6 99.9%NEW 1GB RAM+16GB ROM 1810mAh Sin...     ₦65,906

# %%
# Convert the DataFrame's column names to a list and print the string representation
# repr() shows the exact string representation including quotes and escape characters
print(repr(DataFrame.columns.tolist()))
# Out:
# ['Phone_info', 'Phone_Price']

# %% [markdown]
# ### defining iPhone models in chronological order from iPhone 3G to recent models

# %%
# List of iPhone models in chronological order from iPhone 3G to recent models
# This includes all main iPhone releases, including standard, Plus, Pro, Pro Max, mini, SE, and Air variants
# The list spans from early models (3G, 4, 5 series) through current models (16 and 17 series)
models = [
    'iPhone 3G', 'iPhone 3GS', 'iPhone 4', 'iPhone 4s', 'iPhone 5', 
    'iPhone 5c', 'iPhone 5s', 'iPhone 6', 'iPhone 6 Plus', 'iPhone 6s', 
    'iPhone 6s Plus', 'iPhone SE', 'iPhone 7', 'iPhone 7 Plus', 'iPhone 8', 
    'iPhone 8 Plus', 'iPhone X', 'iPhone XS', 'iPhone XS Max', 'iPhone XR', 
    'iPhone 11', 'iPhone 11 Pro', 'iPhone 11 Pro Max', 'iPhone 12', 
    'iPhone 12 mini', 'iPhone 12 Pro', 'iPhone 12 Pro Max', 'iPhone 13', 
    'iPhone 13 mini', 'iPhone 13 Pro', 'iPhone 13 Pro Max', 'iPhone 14', 
    'iPhone 14 Plus', 'iPhone 14 Pro', 'iPhone 14 Pro Max', 'iPhone 15', 
    'iPhone 15 Plus', 'iPhone 15 Pro', 'iPhone 15 Pro Max', 'iPhone 16', 
    'iPhone 16 Plus', 'iPhone 16 Pro', 'iPhone 16 Pro Max', 'iPhone 16e', 
    'iPhone 17', 'iPhone Air', 'iPhone 17 Pro', 'iPhone 17 Pro Max'
]

# %% [markdown]
# ### Sorting the models

# %%
# Sort the 'models' list by length of each element in descending order (longest first)
sorted_models = sorted(models, key=len, reverse=True)

# %%
# Create an empty list to store the identified phone series
series_list = []
# Iterate through each phone information entry in the DataFrame
for name in DataFrame['Phone_info']:
    # Check if the phone information is missing (NaN)
    if pd.isna(name):
        # If missing, label as 'Unknown'
        series_list.append('Unknown')
    else:
        # Convert phone information to lowercase for case-insensitive matching
        name_lower = str(name).lower()
        # Default value if no match is found
        found = 'Unknown'
        # Iterate through the sorted list of phone models
        for model in sorted_models:
            # Check if the current model appears in the phone information
            if model.lower() in name_lower:
                # If found, assign the model name and stop searching
                found = model
                break
        # Add the identified model to the list
        series_list.append(found)

# Create a new column 'Series' in the DataFrame with the identified phone models
DataFrame['Series'] = series_list

# %% [markdown]
# ### Finding duplicate rows in DataFrame based on 'Phone_info', 'Series', and 'Phone_Price'

# %%
# Find duplicate rows in DataFrame based on 'Phone_info', 'Series', and 'Phone_Price' columns
# keep=False ensures all duplicates are marked (not just first or last occurrences)
duplicates = DataFrame[DataFrame.duplicated(subset=['Phone_info', 'Series', 'Phone_Price'], keep=False)]
print(duplicates)  # Display all identified duplicate rows
# Out:
#                                             Phone_info Phone_Price  \
# 0    Apple IPhone 11 6.1-Inch Liquid Retina LCD (4G...    ₦500,000
# 1    Apple IPhone 12 Pro Max - 6.7-Inch - 128GB ROM...    ₦690,000
# 2       Apple IPhone 16 - 8GB-256GB - 5G - Ultramarine  ₦1,899,000
# 4    IPhone 6 99.9%NEW 1GB RAM+16GB ROM 1810mAh Sin...     ₦65,906
# 16   IPhone 6 99.9%NEW 1GB RAM+16GB ROM 1810mAh Sin...     ₦65,906
# ..                                                 ...         ...
# 583  Otg 64GB Ultra OTG Micro USB Type-c Lightning ...     ₦14,900
# 586  K9 Dual Wireless Lapel Microphone Lavalier Mic...     ₦11,300
# 595    Pro 5s EarPod For IOS(iPhone) & Android Devices      ₦6,000
# 613  Apple IPhone 16 Pro Max - 8GB - 512GB - Single...  ₦2,150,000
# 633  Apple iPhone 16 Pro Max - 8GB - 256GB -5G - De...  ₦1,920,999
#
#                 Series
# 0            iPhone 11
# 1    iPhone 12 Pro Max
# 2            iPhone 16
# 4             iPhone 6
# 16            iPhone 6
# ..                 ...
# 583            Unknown
# 586            Unknown
# 595            Unknown
# 613  iPhone 16 Pro Max
# 633  iPhone 16 Pro Max
#
# [150 rows x 3 columns]

# %% [markdown]
# ### Removing duplicates

# %%
# Remove duplicate rows from DataFrame based on 'Series' and 'Phone_Price' columns
# This keeps only the first occurrence of each unique combination
df_clean = DataFrame.drop_duplicates(subset=['Series', 'Phone_Price'])

# %% [markdown]
# ### Checking the rows doesn't match the defined iphone model

# %%
# Filter the dataframe to only include rows where 'Series' column equals 'Unknown'
# and store the result in a new dataframe called 'Unknown'
Unknown = df_clean[df_clean['Series'] == 'Unknown']
# Display the contents of the 'Unknown' dataframe
print(Unknown)
# Out:
#                                             Phone_info Phone_Price   Series
# 3    PHILLY 50W Iphone Type-c To Lighting  Fast  Ch...      ₦3,912  Unknown
# 10   K9 Double Wireless Lapel Microphone Tie Mic TY...      ₦9,197  Unknown
# 11   Holder Portable Phone Holder Mobile IPhone, Sm...      ₦2,700  Unknown
# 15   Ace-Type TypeC Charger 120W Fast Android USB C...      ₦5,529  Unknown
# 19   K9 Dual Wireless Lapel Microphone Lavalier Tie...     ₦10,643  Unknown
# ..                                                 ...         ...      ...
# 627  Realme earbuds NEWAGE Wireless Earphones Bluet...     ₦16,765  Unknown
# 629  Oraimo Firefly 3 10W Fast IPhone Charger + Lig...      ₦7,495  Unknown
# 634  DUAL Type-c Wireless Lapel Microphone For IPho...     ₦13,980  Unknown
# 635  X2 Newest Long Battery Life Simple And Compact...     ₦18,523  Unknown
# 638  Flick 50000 MAH Large Capacity Full For IPhone...     ₦36,000  Unknown
#
# [210 rows x 3 columns]

# %% [markdown]
# ### Display all unknown entries for futher inspection before dropping it

# %%
# Temporarily set pandas to display all rows
pd.set_option('display.max_rows', None)

# Display the entire Unknown DataFrame
print(Unknown[['Phone_info', 'Phone_Price', 'Series']])

# Optional: reset the option back to default to avoid huge outputs later
pd.reset_option('display.max_rows')
# Out:
#                                             Phone_info      Phone_Price  \
# 3    PHILLY 50W Iphone Type-c To Lighting  Fast  Ch...           ₦3,912
# 10   K9 Double Wireless Lapel Microphone Tie Mic TY...           ₦9,197
# 11   Holder Portable Phone Holder Mobile IPhone, Sm...           ₦2,700
# 15   Ace-Type TypeC Charger 120W Fast Android USB C...           ₦5,529
# 19   K9 Dual Wireless Lapel Microphone Lavalier Tie...          ₦10,643
# 23   K9 Double Wireless Lapel Microphone Tie Mic TY...           ₦9,454
# 31   HEAVY DUTY 120W SMART IPHONE USB-C To LIGHTING...           ₦4,940
# 34   Holder Portable Phone Holder Mobile IPhone, Sm...           ₦3,267
# 35                    Apple iPhone 16 (256 GB) – Black       ₦1,370,446
# 36   TiLECC Wireless Lapel Microphone Type-c For IP...          ₦11,200
# 37   Double Wireless Microphone TYPE-C Android Phon...           ₦9,200
# 48   Hollyland Lark M1 Wireless Lavalier Microphone...          ₦47,081
# 61   Wireless Music Wireless Bluetooth Earphone 5.0...           ₦4,850
# 65   Holder Portable Phone Holder Mobile IPhone, Sm...           ₦3,100
# 68     Pro 5s EarPod For IOS(iPhone) & Android Devices    ₦5,940-₦6,000
# 75   K9 Double Wireless Lapel Microphone Tie Mic TY...           ₦9,223
# 81     Pro 5s EarPod For IOS(iPhone) & Android Devices           ₦6,000
# 83   Wireless Music Wireless Bluetooth Earphone 5.0...           ₦4,960
# 95   Wireless Stereo Earphone Newage EarPhone Bluet...          ₦12,930
# 98   TiLECC TiLECC Wireless Lavalier Microphone Por...           ₦6,774
# 101  Dual Wireless Lavalier Microphone TYPE-C Andro...          ₦12,400
# 103  Air Pro 9s Super Bass Wireless Bluetooth Earpo...           ₦4,999
# 104  Wireless MS-T Bluetooth headphones Headset hea...          ₦11,960
# 105  Pro5s EarPod Heavy Bass For IOS(iPhone) & Andr...    ₦6,000-₦6,500
# 106  K9 3-in-1 Dual Wireless Lapel Microphone Laval...          ₦16,995
# 107  Apple Piler HIGH QUALITY Wrist Watch Bracelet ...          ₦13,990
# 108  F11-2  Dual Noise Cancelling Wireless Micropho...          ₦29,990
# 109    Pro 5s EarPod For IOS(iPhone) & Android Devices           ₦7,900
# 110  New Age  Connect Prime 4 65W (4-in-1 Multiport...           ₦3,500
# 111  Smile IPhone Case Pouch - X,11,12,13,14,15,16 ...    ₦4,550-₦5,600
# 115  WIRELESS CHARGER Magnetic Wireless Fast Charge...           ₦5,000
# 117  WHITE - Silicon Pro IPhone Case Pouch - X,XR,1...    ₦3,550-₦4,999
# 121  Asni For Men HIGH QUALITY Wrist Watch Bracelet...          ₦13,700
# 123  K9 Dual Wireless Lapel Microphone Lavalier Mic...          ₦11,300
# 124  Wireless Lavalier Microphone (2-Pack) With LED...          ₦18,600
# 125  Pink portable keychain charger with 1500mAh wi...           ₦3,565
# 127  BOMGE Wireless Lavalier Microphone, With Charg...          ₦28,966
# 128  Dual Wireless Lapel Microphone Lavalier Mic TY...          ₦10,500
# 129  For IPhone & Android + IOS Adapter Single Type...           ₦9,700
# 131  BLACK - Silicon Pro IPhone Case Pouch - X,XS,X...    ₦3,555-₦3,700
# 133  WIRELESS CHARGER Wireless Phone Charger IPhone...           ₦7,500
# 135  BOMGE Wireless Lavalier Microphone, With Charg...          ₦28,100
# 139  Ace-Type 20W Iphone Type C Fast Data TypeC To ...           ₦2,500
# 145  Samsung USB Lightning To 35mm Aux Audio Headph...           ₦2,999
# 147  Wireless Stereo Earphone Wireless Earpiece 5 3...           ₦7,250
# 148  Bolizma TWS Hi-Fi Stereo Wireless Earbuds- In-...          ₦12,080
# 149  Microphone Podcast Condenser Microphone Stand ...          ₦39,500
# 151  Asni For Men Waterproof Swimming Leather Origi...          ₦20,900
# 152  Holder  Portable Magnetic Phone-Holder Mobile ...          ₦14,999
# 158          6 In 1 2PD 2USB Iphone Cable/Type-C Cable          ₦11,005
# 160  Adjustable IPhone Desktop Mobile Phone Stand H...           ₦4,000
# 161  M9 Pro Magnetic Dual Noise Cancelling Wireless...          ₦39,990
# 165  addigoes Wireless Microphone for iPhone, Andro...          ₦16,304
# 166  addigoes Phone Tripod, 58" Tripod for Phone St...          ₦26,496
# 168  Holder Portable Phone Holder_Mobile IPhone, Sm...           ₦4,200
# 171  Air Pro 9s Super Bass Wireless Bluetooth Earpo...           ₦4,800
# 173        Adjustable Mobile Phone Stand IPhone Holder           ₦2,900
# 175  Wireless Lapel Microphone Tie Mic TYPE-C Phone...          ₦24,500
# 176  TYPE A1 20w 1.5 meter long Fast Charge Type C ...           ₦3,990
# 177  YUUIKLLE 66W Retractable 4-in-1 Fast Car Charg...          ₦18,960
# 179  60,000mah 100w heavy duty super fast charging ...          ₦85,999
# 180  V8 Fashion Phone Bluetooth Wireless Mobile Pho...          ₦13,399
# 182  Lightning To 3.5mm JackAdapter For IPhone IPad...           ₦2,790
# 188  Apple Piler Smart Watch Waterproof Smart I Wat...          ₦20,890
# 190  20W Iphone Usb-c To Lightning PD Fast Lightnin...           ₦6,999
# 192  Wireless Stereo Earphone Wireless Earpiece 5 3...           ₦8,500
# 195  Universal 3-in-1 USB Cellphone Cables, Multipl...           ₦3,252
# 196  Black mini keychain  power bank; small portabl...           ₦3,410
# 197               USB Type C To OTG Adapter For IPhone           ₦3,000
# 199  For IPhone & Android + IOS Adapter Single Type...          ₦10,980
# 200  45W super fast charging suitable for Samsung i...           ₦5,425
# 205  liquid silicone IPhone Case  X,XS---15,16 PRO MAX    ₦3,800-₦4,000
# 209   Otg IPhone  To Type A USB 3.0 Flash Drive Reader           ₦2,800
# 211  Realme earbuds Wireless Bluetooth Headphones H...          ₦10,970
# 212  K9 Dual Wireless Lapel Microphone Lavalier Mic...           ₦9,500
# 213  Microphone K9 Dual 2 In 1 Wireless Lavalier Mi...          ₦10,900
# 215  Wireless Lapel Microphone Type-c For IPhone An...          ₦27,281
# 216  Adjustable IPhone Desktop Mobile Phone Stand H...           ₦3,300
# 219  SHPLUS 36W IPhone Timing Function Fast Adpter ...    ₦5,600-₦6,200
# 220  Cover 3PCS WebCam Front Camera Cover  Slider P...           ₦1,750
# 222  TYPE A1 20W 1.5meter Braided Fast Charge ORIGI...           ₦3,995
# 223  BOMGE Wireless Lapel Microphone Tie Mic TYPE-C...          ₦12,865
# 224  Otg 3in1 IPhone OTG Typec Micro USB 3.0 Flash ...           ₦4,750
# 226  Realme earbuds Wireless Bluetooth Earphones He...          ₦11,950
# 230  Microphone HIGH QUALITY Tie Clip ORIGINAL IPho...           ₦5,999
# 231  25W Type C Fast Charger For IPhone Samsung And...           ₦4,900
# 234  Microphone K9 Wireless Lavalier Microphone For...          ₦10,299
# 237  Super Fast 65W 4-in-1 USB-C Cable, PD 65W Fast...    ₦2,847-₦5,510
# 238  T55 SMART WATCH Smart Wrist Watch Bracelet For...          ₦14,000
# 241  Havit EarPhone Bluetooth Android And Iphone Ea...          ₦23,000
# 242  Realme Wireless Wireless Earbuds Bluetooth F9 ...           ₦7,200
# 244  Otg 64GB Ultra OTG Micro USB Type-c Lightning ...          ₦14,900
# 245  Magnetic Magsafe Wireless Charger For Iphone &...           ₦5,290
# 247  Apple Headphone/Lightning Adapter to 3.5mm Ear...           ₦3,650
# 248  Bluetooth Headphones with Digital LED Display ...           ₦3,875
# 250  Rechargeable Bluetooth Keyboard And Mouse For ...          ₦15,000
# 254  Ace-Type 20W Iphone Type C Fast Data TypeC To ...           ₦4,250
# 256  iPhone  16 Promax/16 Pro/16/15 Promax/15 Pro/1...    ₦2,300-₦2,500
# 257  DUAL SHOCK Vibration Bluetooth Wireless Mobile...          ₦13,400
# 262  Mini Wireless Tie Microphone Lavalier Micropho...           ₦9,884
# 267  Body Mic Wireless 3 in 1 Microphone for iPhone...          ₦21,100
# 269  Y13 Smartwatch (2025, 1.83” HD Display) – Blue...          ₦16,000
# 276  35W Fast Charger USB-C Power Adapter For Iphon...           ₦5,500
# 284  Dual Noise Cancelling Wireless F11-2 Microphon...          ₦21,999
# 285  3PCS WebCam Front Camera Cover Slider Plastic ...             ₦940
# 289  2N1 Wireless Collar Microphone With Furry Squa...          ₦21,010
# 291  USB Micro SD Card Reader, 4in1 Type C & USB A ...           ₦4,490
# 292  Mobile Phone Cooler,USB Game Cooling Fan Holde...          ₦13,950
# 298  Lightning Audio ORIGINAL Aux Cable For All Iph...           ₦3,799
# 299  Type-C Port Wireless Clip-On Microphone With C...          ₦34,981
# 300  F11-2 Dual Noise Cancelling Wireless Microphon...          ₦25,000
# 303  Type Z IPhone, IPad Fast Charger 2.4A Cable Fo...           ₦4,990
# 304  Wireless MS-T 22.5W Output & 15W Wireless Supe...          ₦18,500
# 308  itel Strong Wireless ITEL BUDS NEO Earbuds Blu...          ₦15,590
# 309  Silicon pro IPhone Case 16/ 16plus/ 16pro/ 16p...           ₦3,999
# 313  Hollyland Hollyland A1 Combo - Wireless Mini M...          ₦95,840
# 314  Chupez Otg 128GB Ultra Micro USB Type-c Lightn...          ₦19,899
# 317  15W Wireless Fast Charger For Android, Samsung...           ₦8,950
# 320  Portable Wireless Bluetooth Keyboard And Mouse...          ₦16,500
# 321  IPhone To 3.5mm Jack Audio Extension Cable Aux...           ₦4,500
# 327  Powrennax 30000mah Wireless Power Bank Battery...          ₦35,000
# 328  Type Z Fast Type - C IPhone Charger Head And C...           ₦5,300
# 331    Pro 5s EarPod For IOS(iPhone) & Android Devices           ₦7,400
# 335    Pro 5s EarPod For IOS(iPhone) & Android Devices           ₦7,000
# 338  Holder Portable Phone Holder Mobile Compatible...           ₦3,400
# 341  Realme Wireless Sleek Wireless Earbuds Bluetoo...          ₦11,500
# 346  EarPhone Bluetooth For Android And Iphone Earp...          ₦12,920
# 347  Flick  80'000MAH  2 Inbuilt Cable Super Large ...          ₦85,000
# 349  Otg IPhone OTG To Type A USB 3.0 Flash Drive R...           ₦2,750
# 351  BLUETOOTH ZONE NEWAGE Bluetooth Pods Wireless ...          ₦16,650
# 357  3000MAH  3 In 1 Mini PowerBank Exchangeable Pi...          ₦15,999
# 359  EBXYA External USB Sound Card 192KHz - Type-C ...          ₦86,645
# 362       Lightning To 3.5MM Digital Audio IPhone Jack           ₦3,200
# 363  4 USB Chargers 66W PD Type C Fast Charging Wal...          ₦10,000
# 366  10in1 Smart Watch Ultra 8 NFC GPS Track Men Wo...          ₦30,000
# 367  1PCS UNIVERSAL STYLUS PEN FOR IOS,ANDROID,WIND...           ₦6,006
# 368  I8 Series 8 Ultra SMART WRISTWATCH WITH AIRPOD...          ₦28,000
# 370  X2 Simple And Compact Earbuds Wireless Noise R...          ₦18,452
# 375  K9 Single Wireless Lapel Microphone Lavalier M...           ₦9,950
# 378  4 in 1 Wireless Lavalier Dual Noise Cancellati...          ₦19,990
# 382  Adapter OTG Tpye-c IPhone Flash Drive Audio Black           ₦4,288
# 383  Dual Wireless Microphone For IPhone & Type-C +...          ₦11,250
# 384  Livestream Sound Card Professional Volume Adju...          ₦29,650
# 389  NEW Wave Pattern IPhone Case/Pouch - X,XS,XR,1...    ₦3,350-₦6,000
# 392  Phone Cooler with Back Clip,Fast Semiconductor...          ₦10,835
# 393  2Pcs Silicone Suction Phone Case Adhesive Moun...           ₦3,085
# 395  K9 Dual Wireless Lapel Microphone Lavalier Mic...          ₦12,995
# 396  Zealot Wireless Stereo Earphone Wireless Bluet...          ₦17,000
# 398  K9 Dual Wireless Microphone TYPE-C Android IPh...          ₦10,895
# 399  Large 26CM Selfie Ring Light With Tripod Stand...          ₦18,990
# 403  PRO Lavalier Wireless Microphone 3 In 1 for Vi...          ₦11,270
# 417  TWS in-ear headphones, 9D stereo, HD audio, cl...           ₦8,990
# 419  35W Iphone USB-C To Lightning PD Fast Lightnin...           ₦5,680
# 423  SHPLUS Type C+ USB ANDROID IPHONE Charger PD C...           ₦6,900
# 424  SanDisk 32GB Ultra Memory Card SDHC Card C10 (...           ₦6,600
# 435  USB Flash Drive Photo Stick 4 In 1 USB 3.0 Hig...          ₦39,000
# 436  3-In-1 Lightning SD/USB Reader For IPhone/iPad...          ₦12,998
# 439  Wireless Audio, Video Recording Microphone For...          ₦13,550
# 440                  USB Fast Charger Cable For IPhone           ₦2,400
# 441  Otg USB 3.0 OTG Adapter Compatible With Iphone...           ₦5,490
# 443  K9 Microphone Dual Wireless Microphone TYPE-C ...          ₦10,999
# 446  F11-2 Dual Noise Cancelling Wireless Microphon...          ₦22,500
# 448  Lightning To 3.5MM Pin Mouth Digital Audio IPh...           ₦2,998
# 457  WIRELESS CHARGER Wireless Phone Charger IPhone...           ₦7,800
# 459  Otg IPhone OTG To Type A USB 3.0 Flash Drive R...           ₦3,499
# 463  Air Pro 3wireless Bluetooth Earpods For IPhone...           ₦6,500
# 465  Flick 50000 MAH Large Capacity Full Backup Bat...          ₦33,500
# 467  addigoes Wireless Lavalier Microphone, 130 ft ...          ₦40,768
# 469  Oraimo IPhone 2.4A Fast Charging USB Lightning...           ₦1,700
# 474  F11-2 Dual Noise Cancelling Wireless Microphon...          ₦22,900
# 479  K9 Dual Wireless Microphone For IPhone & Andro...           ₦9,550
# 490  Wireless Music Wireless Bluetooth Earphone 5.0...           ₦5,900
# 494  X5 New Invisible In Ear Wireless Noise Reducti...          ₦16,876
# 496  Mniboom Bluetooth Speaker Bluetooth For Androi...          ₦18,899
# 503  12"inches  Selfie Ring Light With Tripod Stand...          ₦16,990
# 508  Aux Cable For IPhone Lightning Car To 3.5mm Jà...           ₦3,998
# 509                       USB Cable Charger For IPhone           ₦2,200
# 511  Buda F9 5.0 Wireless Sports Headset Ear Phone ...           ₦9,450
# 512  WIRELESS CHARGER Havit Wireless Phone Charger ...          ₦39,200
# 518  Pro5s EarPod Heavy Bass For IOS(iPhone) & Andr...    ₦6,999-₦7,500
# 520  Microphone Professional Condenser Recording Mi...           ₦5,760
# 521  Thinkcar Thinkdiag OBD2 Scanner Bluetooth For ...         ₦170,000
# 523  USB OTG Adapter For IPhone Lightning IOS 13 14...           ₦5,800
# 525  Fast 35W Type C Fast Charger Only Head For Sam...           ₦4,400
# 526  Anycast HDMI M9 PLUS Wireless HDMI TV Same Scr...          ₦15,400
# 536  70W Fast USB Type C Original Charger For 14, 1...          ₦11,000
# 540  Double Wireless Microphone TYPE-C Android Phon...          ₦12,999
# 541  Fit Type A pattern Original Type C Earpiece - ...           ₦4,019
# 543    Pro 5s EarPod For IOS(iPhone) & Android Devices           ₦8,900
# 549  Thinkcar Thinkdiag OBD2 Scanner Bluetooth For ...         ₦179,999
# 551             Usb Power Fast Charge IPhone USB Cable           ₦2,300
# 556  Wireless Music Wireless Bluetooth Earphone 5.0...           ₦4,699
# 557  SX21 Magnetic Lavalier Microphone With POWERBA...          ₦27,550
# 560  TWS in-ear headphones, 9D stereo, HD audio, cl...           ₦7,600
# 568      MULTI TYPE C & IPHONE CORD CHARGER SUPER-FAST           ₦3,325
# 570   Pro 5s Earbuds For IOS(iPhone) & Android Devices           ₦6,200
# 574  50 Watts Dual Port Charger For Iphones XR TO 1...           ₦5,400
# 576  WIRELESS CHARGER Wireless Phone Charger IPhone...          ₦15,900
# 579  3-in-1 Dual Wireless Microphone Lavalier Lapel...          ₦19,500
# 581  3 In 1 Wireless Lapel Microphone For Android/ ...          ₦34,500
# 584  Obdlink Mx Bluetooth EarPhone Bluetooth For An...  ₦14,720-₦14,920
# 593  65W Super Fast Charger Adaptive Charging For A...           ₦8,200
# 594  K9 Dual Wireless Microphone For IPhone & Andro...          ₦13,995
# 612  Magnetic Wireless Charger With Fast Charging C...           ₦9,000
# 619  Way 01 New Bluetooth Remote Controller Hand-he...           ₦4,300
# 627  Realme earbuds NEWAGE Wireless Earphones Bluet...          ₦16,765
# 629  Oraimo Firefly 3 10W Fast IPhone Charger + Lig...           ₦7,495
# 634  DUAL Type-c Wireless Lapel Microphone For IPho...          ₦13,980
# 635  X2 Newest Long Battery Life Simple And Compact...          ₦18,523
# 638  Flick 50000 MAH Large Capacity Full For IPhone...          ₦36,000
#
#       Series
# 3    Unknown
# 10   Unknown
# 11   Unknown
# 15   Unknown
# 19   Unknown
# 23   Unknown
# 31   Unknown
# 34   Unknown
# 35   Unknown
# 36   Unknown
# 37   Unknown
# 48   Unknown
# 61   Unknown
# 65   Unknown
# 68   Unknown
# 75   Unknown
# 81   Unknown
# 83   Unknown
# 95   Unknown
# 98   Unknown
# 101  Unknown
# 103  Unknown
# 104  Unknown
# 105  Unknown
# 106  Unknown
# 107  Unknown
# 108  Unknown
# 109  Unknown
# 110  Unknown
# 111  Unknown
# 115  Unknown
# 117  Unknown
# 121  Unknown
# 123  Unknown
# 124  Unknown
# 125  Unknown
# 127  Unknown
# 128  Unknown
# 129  Unknown
# 131  Unknown
# 133  Unknown
# 135  Unknown
# 139  Unknown
# 145  Unknown
# 147  Unknown
# 148  Unknown
# 149  Unknown
# 151  Unknown
# 152  Unknown
# 158  Unknown
# 160  Unknown
# 161  Unknown
# 165  Unknown
# 166  Unknown
# 168  Unknown
# 171  Unknown
# 173  Unknown
# 175  Unknown
# 176  Unknown
# 177  Unknown
# 179  Unknown
# 180  Unknown
# 182  Unknown
# 188  Unknown
# 190  Unknown
# 192  Unknown
# 195  Unknown
# 196  Unknown
# 197  Unknown
# 199  Unknown
# 200  Unknown
# 205  Unknown
# 209  Unknown
# 211  Unknown
# 212  Unknown
# 213  Unknown
# 215  Unknown
# 216  Unknown
# 219  Unknown
# 220  Unknown
# 222  Unknown
# 223  Unknown
# 224  Unknown
# 226  Unknown
# 230  Unknown
# 231  Unknown
# 234  Unknown
# 237  Unknown
# 238  Unknown
# 241  Unknown
# 242  Unknown
# 244  Unknown
# 245  Unknown
# 247  Unknown
# 248  Unknown
# 250  Unknown
# 254  Unknown
# 256  Unknown
# 257  Unknown
# 262  Unknown
# 267  Unknown
# 269  Unknown
# 276  Unknown
# 284  Unknown
# 285  Unknown
# 289  Unknown
# 291  Unknown
# 292  Unknown
# 298  Unknown
# 299  Unknown
# 300  Unknown
# 303  Unknown
# 304  Unknown
# 308  Unknown
# 309  Unknown
# 313  Unknown
# 314  Unknown
# 317  Unknown
# 320  Unknown
# 321  Unknown
# 327  Unknown
# 328  Unknown
# 331  Unknown
# 335  Unknown
# 338  Unknown
# 341  Unknown
# 346  Unknown
# 347  Unknown
# 349  Unknown
# 351  Unknown
# 357  Unknown
# 359  Unknown
# 362  Unknown
# 363  Unknown
# 366  Unknown
# 367  Unknown
# 368  Unknown
# 370  Unknown
# 375  Unknown
# 378  Unknown
# 382  Unknown
# 383  Unknown
# 384  Unknown
# 389  Unknown
# 392  Unknown
# 393  Unknown
# 395  Unknown
# 396  Unknown
# 398  Unknown
# 399  Unknown
# 403  Unknown
# 417  Unknown
# 419  Unknown
# 423  Unknown
# 424  Unknown
# 435  Unknown
# 436  Unknown
# 439  Unknown
# 440  Unknown
# 441  Unknown
# 443  Unknown
# 446  Unknown
# 448  Unknown
# 457  Unknown
# 459  Unknown
# 463  Unknown
# 465  Unknown
# 467  Unknown
# 469  Unknown
# 474  Unknown
# 479  Unknown
# 490  Unknown
# 494  Unknown
# 496  Unknown
# 503  Unknown
# 508  Unknown
# 509  Unknown
# 511  Unknown
# 512  Unknown
# 518  Unknown
# 520  Unknown
# 521  Unknown
# 523  Unknown
# 525  Unknown
# 526  Unknown
# 536  Unknown
# 540  Unknown
# 541  Unknown
# 543  Unknown
# 549  Unknown
# 551  Unknown
# 556  Unknown
# 557  Unknown
# 560  Unknown
# 568  Unknown
# 570  Unknown
# 574  Unknown
# 576  Unknown
# 579  Unknown
# 581  Unknown
# 584  Unknown
# 593  Unknown
# 594  Unknown
# 612  Unknown
# 619  Unknown
# 627  Unknown
# 629  Unknown
# 634  Unknown
# 635  Unknown
# 638  Unknown

# %% [markdown]
# ### chehcking the rows of the cleaned DataFrame

# %%
# Get the number of rows in the cleaned DataFrame
len(df_clean)
# Out:
# 436

# %%
# Randomly display 10 rows from the cleaned DataFrame
df_clean.sample(10)
# Out:
#                                             Phone_info    Phone_Price  \
# 383  Dual Wireless Microphone For IPhone & Type-C +...        ₦11,250
# 194  Apple iPhone 17 Pro Max 5G 6.9'' 12GB RAM 2TB ...     ₦5,250,000
# 163  IPhone 15/ 15plus/15 Pro/15pro Max/16/16plus/1...         ₦6,999
# 631  Iphone 17 pro max transparent shockproof back ...         ₦3,500
# 317  15W Wireless Fast Charger For Android, Samsung...         ₦8,950
# 151  Asni For Men Waterproof Swimming Leather Origi...        ₦20,900
# 626  Camera Lens Shield Protector For IPhone 11/12/...         ₦2,890
# 147  Wireless Stereo Earphone Wireless Earpiece 5 3...         ₦7,250
# 606  100WD Liquid Silicone Case For IPhone 13, 12, ...  ₦5,000-₦5,800
# 74   IPhone 6 99.9%NEW 1GB RAM+32GB ROM 1810mAh Sin...        ₦68,898
#
#                 Series
# 383            Unknown
# 194  iPhone 17 Pro Max
# 163          iPhone 15
# 631  iPhone 17 Pro Max
# 317            Unknown
# 151            Unknown
# 626          iPhone 11
# 147            Unknown
# 606          iPhone 13
# 74            iPhone 6

# %% [markdown]
# ### Inspecting iPhone 16 Pro Max

# %%
# Filter the dataset to include only rows where the Series column equals "iPhone 16 Pro Max"
iphone_16_pro_max = df_clean[df_clean['Series'] == 'iPhone 16 Pro Max']

# Print the filtered DataFrame to view the records for iPhone 16 Pro Max
print(iphone_16_pro_max)
# Out:
#                                             Phone_info Phone_Price  \
# 8    Apple IPhone 16 Pro Max  - 8GB - 256GB -5G - B...  ₦2,299,000
# 20   Apple IPhone 16 Pro Max  - 8GB - 512GB -5G - N...  ₦2,750,000
# 46   Apple IPhone 16 Pro Max - 8GB - 512GB - Single...  ₦2,150,000
# 82   Apple iPhone 16 Pro Max (256 GB) – Black Titanium  ₦1,953,407
# 87   Apple iPhone 16 Pro Max - 8GB - 256GB -5G - De...  ₦1,920,999
# 307  Designer IPhone 16 Pro Max Case - Fashionable ...     ₦17,000
# 418       Xundd Transparent Case For Iphone 16 Pro Max     ₦14,000
# 517  IPhone 16 Pro Max Silicone Phone Case & Pouch ...      ₦4,741
# 529  IPhone 16 Pro Max /16 Pro/16 /16 Plus Full Scr...      ₦4,500
# 567  Rugged Case With Built-in Screen Guard For IPh...     ₦15,000
# 600  Designer IPhone 16 Pro Max Case - Fashionable ...     ₦17,500
# 609  Iphone 16 Pro Max Jelly Liquid Silicone Phone ...      ₦9,000
#
#                 Series
# 8    iPhone 16 Pro Max
# 20   iPhone 16 Pro Max
# 46   iPhone 16 Pro Max
# 82   iPhone 16 Pro Max
# 87   iPhone 16 Pro Max
# 307  iPhone 16 Pro Max
# 418  iPhone 16 Pro Max
# 517  iPhone 16 Pro Max
# 529  iPhone 16 Pro Max
# 567  iPhone 16 Pro Max
# 600  iPhone 16 Pro Max
# 609  iPhone 16 Pro Max

# %% [markdown]
# ### Inspecting iPhone 16

# %%
# Filter the dataframe to get only rows where the Series is "iPhone 16"
iphone_16 = df_clean[df_clean['Series'] == 'iPhone 16']

# Display the filtered result
print(iphone_16)
# Out:
#                                             Phone_info    Phone_Price  \
# 2       Apple IPhone 16 - 8GB-256GB - 5G - Ultramarine     ₦1,899,000
# 172  Type Z FOR Charger USB Type C To Type C IPhone...         ₦4,995
# 253  For IPhone 16 Silicone Fine Pore Phone Case(La...         ₦5,300
# 278  Type Z FOR Charger USB Type C To Type C IPhone...         ₦4,900
# 337  IPhone 16 High Quality Protective Transparent ...         ₦2,700
# 345                      Iphone 16 white silicone case         ₦4,000
# 364  MagSafe Magnetic Wireless PowerBank 5,000mAh -...        ₦16,141
# 387  Dual Type C Ports For Fast Charging For IPhone...         ₦5,900
# 445  Dual Type C Ports for Fast charging For iPhone...  ₦5,550-₦5,700
# 453  65W  Type C To Type C Charger For Iphone 16, 1...         ₦6,500
# 456  Quality IPHONE 16 Magnetic Magsafe Transparent...         ₦8,500
# 506  iPhone 16 Camera Lens Protector - Camera Prote...         ₦3,791
# 591  Iphone 16/16 Plus/16 Pro/16 Pro Max Quality So...  ₦2,850-₦2,900
# 628  Iphone 16  / 16 Plus Magsafe UltraSlim Hard Ba...         ₦7,999
#
#         Series
# 2    iPhone 16
# 172  iPhone 16
# 253  iPhone 16
# 278  iPhone 16
# 337  iPhone 16
# 345  iPhone 16
# 364  iPhone 16
# 387  iPhone 16
# 445  iPhone 16
# 453  iPhone 16
# 456  iPhone 16
# 506  iPhone 16
# 591  iPhone 16
# 628  iPhone 16

# %% [markdown]
# ### Create a new DataFrame by removing rows where the Series column has the value "Unknown"

# %%
# Create a new DataFrame by removing rows where the Series column has the value "Unknown"
# reset_index(drop=True) resets the index after filtering so it starts from 0 again
df1 = df_clean[df_clean['Series'] != 'Unknown'].reset_index(drop=True)

# Display the cleaned DataFrame
df1
# Out:
#                                             Phone_info Phone_Price  \
# 0    Apple IPhone 11 6.1-Inch Liquid Retina LCD (4G...    ₦500,000
# 1    Apple IPhone 12 Pro Max - 6.7-Inch - 128GB ROM...    ₦690,000
# 2       Apple IPhone 16 - 8GB-256GB - 5G - Ultramarine  ₦1,899,000
# 3    IPhone 6 99.9%NEW 1GB RAM+16GB ROM 1810mAh Sin...     ₦65,906
# 4    Apple IPhone 6s Plus 99.9%NEW 2GB RAM+32GB ROM...     ₦88,907
# ..                                                 ...         ...
# 221  Iphone 16  / 16 Plus Magsafe UltraSlim Hard Ba...      ₦7,999
# 222  Iphone 17 pro max transparent shockproof back ...      ₦3,500
# 223  Fast iPhone 15 pro max PD Car Mp3 Charger Blue...      ₦6,900
# 224                  IPhone 15 Pro Max Direct Earpiece      ₦7,500
# 225  Magnetic Charging Station 100W Wireless Charge...     ₦16,500
#
#                 Series
# 0            iPhone 11
# 1    iPhone 12 Pro Max
# 2            iPhone 16
# 3             iPhone 6
# 4       iPhone 6s Plus
# ..                 ...
# 221          iPhone 16
# 222  iPhone 17 Pro Max
# 223  iPhone 15 Pro Max
# 224  iPhone 15 Pro Max
# 225          iPhone 15
#
# [226 rows x 3 columns]

# %%
# Get unique values from the 'Series' column in df1
# Sort them alphabetically to view in an organized way
print(sorted(df1['Series'].unique()))
# Out:
# ['iPhone 11', 'iPhone 11 Pro Max', 'iPhone 12', 'iPhone 12 Pro', 'iPhone 12 Pro Max', 'iPhone 12 mini', 'iPhone 13', 'iPhone 13 Pro', 'iPhone 13 Pro Max', 'iPhone 14', 'iPhone 14 Plus', 'iPhone 14 Pro', 'iPhone 14 Pro Max', 'iPhone 15', 'iPhone 15 Plus', 'iPhone 15 Pro', 'iPhone 15 Pro Max', 'iPhone 16', 'iPhone 16 Plus', 'iPhone 16 Pro', 'iPhone 16 Pro Max', 'iPhone 17', 'iPhone 17 Pro', 'iPhone 17 Pro Max', 'iPhone 3GS', 'iPhone 6', 'iPhone 6 Plus', 'iPhone 6s Plus', 'iPhone 7', 'iPhone 7 Plus', 'iPhone SE', 'iPhone X', 'iPhone XR', 'iPhone XS', 'iPhone XS Max']

# %% [markdown]
# ### Inpecting iphone 3GS

# %%
# Filter df1 to include only rows where the Series is "iPhone 3GS"
iPhone_3GS = df1[df1['Series'] == 'iPhone 3GS']

# Display the filtered DataFrame to see all records for iPhone 3GS
print(iPhone_3GS)
# Out:
#                                             Phone_info Phone_Price      Series
# 121  2PCS 30 Pin Data Sync Cable, For IPhone 4 & 4S...      ₦5,000  iPhone 3GS

# %% [markdown]
# ### Inpecting iphone 6

# %%
# Filter df1 to include only rows where the Series is "iPhone 6"
iPhone_6 = df1[df1['Series'] == 'iPhone 6']

# Display the filtered DataFrame to see all records for iPhone 6
print(iPhone_6)
# Out:
#                                             Phone_info    Phone_Price  \
# 3    IPhone 6 99.9%NEW 1GB RAM+16GB ROM 1810mAh Sin...        ₦65,906
# 14   Iphone 6 - 4.7" - 1/64GB - 8Mpx - 4G (Recondit...        ₦77,500
# 22   Apple iPhone 6 Renewed 99.9%New 32G Unlocked F...        ₦73,305
# 39   IPhone 6 99.9%NEW 1GB RAM+32GB ROM 1810mAh Sin...        ₦68,898
# 43   Apple IPhone 6 99.9%NEW 1GB RAM+16GB ROM 1810m...        ₦57,949
# 102  4 in 1 USB C iPhone 60W Fast Charging Cable Br...  ₦2,999-₦5,887
# 108  iPhone Crystal Butterfly Star Soft Case For iP...  ₦4,999-₦5,599
# 207  Transparent 360 Degree Touch Case Front And Ba...         ₦2,650
#
#        Series
# 3    iPhone 6
# 14   iPhone 6
# 22   iPhone 6
# 39   iPhone 6
# 43   iPhone 6
# 102  iPhone 6
# 108  iPhone 6
# 207  iPhone 6

# %% [markdown]
# ### Inpecting iPhone 6 plus

# %%
# Filter df1 to include only rows where the Series is "iPhone 6 Plus"
iPhone_6_plus = df1[df1['Series'] == 'iPhone 6 Plus']

# Display the filtered DataFrame to see all records for iPhone 6 Plus
print(iPhone_6_plus)
# Out:
#                                             Phone_info Phone_Price  \
# 90   Classy IPhone 6 Plus /6s Plus Silicone Back Ca...      ₦3,000
# 117  Apple IPhone 6 Plus 6s Plus Case Airbag Cover ...     ₦26,500
# 136  Apple IPhone 6 Plus 6s Plus Case Airbag Cover ...     ₦22,227
# 153  Solid IPhone 6 Plus /6s Plus Silicone Back Cas...      ₦2,000
#
#             Series
# 90   iPhone 6 Plus
# 117  iPhone 6 Plus
# 136  iPhone 6 Plus
# 153  iPhone 6 Plus

# %% [markdown]
# ### Inpecting iphone 6s plus

# %%
# Filter df1 to include only rows where the Series is "iPhone 6s Plus"
iPhone_6s_plus = df1[df1['Series'] == 'iPhone 6s Plus']

# Display the filtered DataFrame to see all records for iPhone 6s Plus
print(iPhone_6s_plus)
# Out:
#                                            Phone_info Phone_Price  \
# 4   Apple IPhone 6s Plus 99.9%NEW 2GB RAM+32GB ROM...     ₦88,907
# 15  Apple IPhone 6s Plus 99.9%NEW 2GB RAM+64GB ROM...     ₦99,003
#
#             Series
# 4   iPhone 6s Plus
# 15  iPhone 6s Plus

# %% [markdown]
# ### Inpecting iphone SE

# %%
# Filter df1 to include only rows where the Series is "iPhone SE"
iPhone_SE = df1[df1['Series'] == 'iPhone SE']

# Display the filtered DataFrame to see all records for iPhone SE
print(iPhone_SE)
# Out:
#                                            Phone_info    Phone_Price  \
# 81  iPhone Series Solid Transparent Case Pouch - M...  ₦3,350-₦6,000
#
#        Series
# 81  iPhone SE

# %% [markdown]
# ### Removing currency symbol, commas and any leading or trailing whitespace

# %%
# Remove the currency symbol (₦) and commas from the 'Phone_Price' column
# Also remove any leading or trailing whitespace
df1['Phone_Price'] = df1['Phone_Price'].str.replace('[₦,]', '', regex=True).str.strip()

# Display the updated DataFrame
df1
# Out:
#                                             Phone_info Phone_Price  \
# 0    Apple IPhone 11 6.1-Inch Liquid Retina LCD (4G...      500000
# 1    Apple IPhone 12 Pro Max - 6.7-Inch - 128GB ROM...      690000
# 2       Apple IPhone 16 - 8GB-256GB - 5G - Ultramarine     1899000
# 3    IPhone 6 99.9%NEW 1GB RAM+16GB ROM 1810mAh Sin...       65906
# 4    Apple IPhone 6s Plus 99.9%NEW 2GB RAM+32GB ROM...       88907
# ..                                                 ...         ...
# 221  Iphone 16  / 16 Plus Magsafe UltraSlim Hard Ba...        7999
# 222  Iphone 17 pro max transparent shockproof back ...        3500
# 223  Fast iPhone 15 pro max PD Car Mp3 Charger Blue...        6900
# 224                  IPhone 15 Pro Max Direct Earpiece        7500
# 225  Magnetic Charging Station 100W Wireless Charge...       16500
#
#                 Series
# 0            iPhone 11
# 1    iPhone 12 Pro Max
# 2            iPhone 16
# 3             iPhone 6
# 4       iPhone 6s Plus
# ..                 ...
# 221          iPhone 16
# 222  iPhone 17 Pro Max
# 223  iPhone 15 Pro Max
# 224  iPhone 15 Pro Max
# 225          iPhone 15
#
# [226 rows x 3 columns]

# %% [markdown]
# ### Converting the 'Phone_Price' column to numeric values

# %%
# Convert the 'Phone_Price' column to numeric values
# If the price is a range (e.g., "1000-1500"), take the average of the two values
# Otherwise, convert the single price string to a float
df1['Phone_Price'] = df1['Phone_Price'].apply(
    lambda x: np.mean([float(p) for p in x.split('-')]) if '-' in x else float(x)
)

# %%
# Filter df1 to include only rows where the Series is "iPhone 6" after cleaning the Phone_Price column
iPhone_6 = df1[df1['Series'] == 'iPhone 6']

# Display the filtered DataFrame to see all iPhone 6 records with numeric prices
print(iPhone_6)
# Out:
#                                             Phone_info  Phone_Price    Series
# 3    IPhone 6 99.9%NEW 1GB RAM+16GB ROM 1810mAh Sin...      65906.0  iPhone 6
# 14   Iphone 6 - 4.7" - 1/64GB - 8Mpx - 4G (Recondit...      77500.0  iPhone 6
# 22   Apple iPhone 6 Renewed 99.9%New 32G Unlocked F...      73305.0  iPhone 6
# 39   IPhone 6 99.9%NEW 1GB RAM+32GB ROM 1810mAh Sin...      68898.0  iPhone 6
# 43   Apple IPhone 6 99.9%NEW 1GB RAM+16GB ROM 1810m...      57949.0  iPhone 6
# 102  4 in 1 USB C iPhone 60W Fast Charging Cable Br...       4443.0  iPhone 6
# 108  iPhone Crystal Butterfly Star Soft Case For iP...       5299.0  iPhone 6
# 207  Transparent 360 Degree Touch Case Front And Ba...       2650.0  iPhone 6

# %% [markdown]
# ### After removing rows and columns labeled as "Unknown," I noticed that some phone accessories were still classified under defined iPhone models. Upon inspection, I found that none of these accessories had prices close to the lowest-priced iPhone in the dataset. To address this, I identified the price of the cheapest iPhone model and removed any items priced below that threshold, ensuring the dataset contains only actual phone entries.

# %%
# Remove rows where the Phone_Price is below 57,949 (because it's the lowest iPhone price)
# Reset the index after filtering to start from 0 again
df1 = df1[df1['Phone_Price'] >= 57949.0].reset_index(drop=True)

# Display the updated DataFrame
df1
# Out:
#                                            Phone_info  Phone_Price  \
# 0   Apple IPhone 11 6.1-Inch Liquid Retina LCD (4G...     500000.0
# 1   Apple IPhone 12 Pro Max - 6.7-Inch - 128GB ROM...     690000.0
# 2      Apple IPhone 16 - 8GB-256GB - 5G - Ultramarine    1899000.0
# 3   IPhone 6 99.9%NEW 1GB RAM+16GB ROM 1810mAh Sin...      65906.0
# 4   Apple IPhone 6s Plus 99.9%NEW 2GB RAM+32GB ROM...      88907.0
# 5   Apple IPhone 11 Pro Max 6.5-Inch (4GB RAM, 256...     615000.0
# 6   Apple IPhone 15 Pro Max 6.7" 512GB Nano-SIM 5G...    1900000.0
# 7   Apple IPhone 16 Pro Max  - 8GB - 256GB -5G - B...    2299000.0
# 8   Apple IPhone 14 Pro Max 6.7" (256GB ROM + 6GB ...    1450000.0
# 9   Apple IPhone 16 Plus 5G - 6.7" - 128GB ROM - 8...    1650000.0
# 10  Apple IPhone 13 - 6.1" - 128GB ROM, 4GB RAM, 3...     720000.0
# 11  Apple IPhone XR - 6.1" - 64GB ROM, 3GB RAM, 29...     760000.0
# 12  Apple IPhone 11 Pro Max 6.5-Inch Super Retina ...     655000.0
# 13  Apple IPhone 16 Pro Max  - 8GB - 512GB -5G - N...    2750000.0
# 14  Iphone 6 - 4.7" - 1/64GB - 8Mpx - 4G (Recondit...      77500.0
# 15  Apple IPhone 6s Plus 99.9%NEW 2GB RAM+64GB ROM...      99003.0
# 16  Apple iPhone 14 Pro Max 6.7" - 256GB ROM - 6GB...    1440000.0
# 17  Apple IPhone 13 Pro Max - 6.7" - 256GB ROM - 6...     950000.0
# 18  Apple IPhone 12, 6.1-Inch 128GB ROM 5G  - Paci...     610000.0
# 19  Apple IPHONE 11 PRO MAX 6.5" (12+12+12PM) 256/...     610000.0
# 20  Apple IPhone 12 6.1 Inches 5GB RAM, 64GB ROM, ...     550000.0
# 21  Apple IPhone 14 Pro 6.1" (128GB ROM + 6GB RAM)...    1150000.0
# 22  Apple iPhone 6 Renewed 99.9%New 32G Unlocked F...      73305.0
# 23  Apple IPhone 12 Pro Max - 6.7Inch - 256GB, 6GB...     740000.0
# 24  Apple IPHONE 12 PRO  (6.1 INCH)  5G (6GB RAM, ...     675000.0
# 25  Apple iPhone 13 Pro 5G - 6.1" 256GB ROM, 6GB R...     835000.0
# 26  Apple IPhone 16 Pro Max - 8GB - 512GB - Single...    2150000.0
# 27  Apple IPhone 12 Pro Max 5G - 6.7" (256GB/6GB) ...     850000.0
# 28  Apple IPhone 13 - 6.1" - 128GB ROM, 4GB RAM, 3...     630000.0
# 29  Apple IPhone 13 Pro Max - 6.7" - 128GB ROM - 6...     898000.0
# 30  Apple IPhone XS Max - 6.5" - 64GB ROM - 4GB RA...     835000.0
# 31  Apple IPhone 11 Pro Max 6.5-Inch (4GB RAM, 256...     680000.0
# 32  Apple IPhone 17 Pro Max - 12GB- 2TB - Cosmic O...    4799000.0
# 33  Apple IPhone 16 Plus 5G - 6.7" - 256GB ROM - 8...    1750000.0
# 34  Apple IPhone 17 Pro - 12GB- 256GB - Cosmic Orange    2499000.0
# 35  Apple IPhone 13 Pro Max - 6.7" 256GB ROM, 6GB ...     980000.0
# 36  Apple IPhone 15 Pro 6.1" (128GB ROM + 8GB RAM)...    1500000.0
# 37  IPhone 6 99.9%NEW 1GB RAM+32GB ROM 1810mAh Sin...      68898.0
# 38  Apple IPhone 12 Pro - 6.1" 128GB ROM, 6GB ROM ...     655000.0
# 39        Apple iPhone 17 Pro Max - 256GB - Deep Blue    2599999.0
# 40  Apple IPhone 6 99.9%NEW 1GB RAM+16GB ROM 1810m...      57949.0
# 41  Apple iPhone 16 Pro Max (256 GB) – Black Titanium    1953407.0
# 42  Apple IPHONE 11 - 6.1"  128/4GB RAM (12MP+12MP...     750000.0
# 43  Apple IPhone 15 5G - 6.1" - 256GB ROM, 6GB ROM...    1045000.0
# 44  Apple iPhone 16 Pro Max - 8GB - 256GB -5G - De...    1920999.0
# 45  Apple iPhone 14 Pro Max 6.7" - 128GB ROM - 6GB...    1330000.0
# 46  Apple IPhone 15 Pro Max 6.7" 256GB Nano-SIM & ...    1800000.0
# 47  Apple iPhone 17 Pro Max - 6.9" - 512GB - 12GB ...    3400000.0
# 48  Hollyland Lark M2 Wireless Lavalier Microphone...     259613.0
# 49  Apple iPhone 17 Pro Max 5G 6.9'' 12GB RAM 2TB ...    5250000.0
# 50  Apple iPhone 17 Pro Max - 6.9" - 256GB - 12GB ...    3000000.0
#
#                Series
# 0           iPhone 11
# 1   iPhone 12 Pro Max
# 2           iPhone 16
# 3            iPhone 6
# 4      iPhone 6s Plus
# 5   iPhone 11 Pro Max
# 6   iPhone 15 Pro Max
# 7   iPhone 16 Pro Max
# 8   iPhone 14 Pro Max
# 9      iPhone 16 Plus
# 10          iPhone 13
# 11          iPhone XR
# 12  iPhone 11 Pro Max
# 13  iPhone 16 Pro Max
# 14           iPhone 6
# 15     iPhone 6s Plus
# 16  iPhone 14 Pro Max
# 17  iPhone 13 Pro Max
# 18          iPhone 12
# 19  iPhone 11 Pro Max
# 20          iPhone 12
# 21      iPhone 14 Pro
# 22           iPhone 6
# 23  iPhone 12 Pro Max
# 24      iPhone 12 Pro
# 25      iPhone 13 Pro
# 26  iPhone 16 Pro Max
# 27  iPhone 12 Pro Max
# 28          iPhone 13
# 29  iPhone 13 Pro Max
# 30      iPhone XS Max
# 31  iPhone 11 Pro Max
# 32  iPhone 17 Pro Max
# 33     iPhone 16 Plus
# 34      iPhone 17 Pro
# 35  iPhone 13 Pro Max
# 36      iPhone 15 Pro
# 37           iPhone 6
# 38      iPhone 12 Pro
# 39  iPhone 17 Pro Max
# 40           iPhone 6
# 41  iPhone 16 Pro Max
# 42          iPhone 11
# 43          iPhone 15
# 44  iPhone 16 Pro Max
# 45  iPhone 14 Pro Max
# 46  iPhone 15 Pro Max
# 47  iPhone 17 Pro Max
# 48          iPhone 15
# 49  iPhone 17 Pro Max
# 50  iPhone 17 Pro Max

# %%
# Get the number of rows in the updated DataFrame after filtering out low-priced entries
len(df1)
# Out:
# 51

# %%
# Filter df1 to include only rows where the Series is "iPhone 6" after removing low-priced entries
iPhone_6 = df1[df1['Series'] == 'iPhone 6']

# Display the filtered DataFrame to verify iPhone 6 records remain
print(iPhone_6)
# Out:
#                                            Phone_info  Phone_Price    Series
# 3   IPhone 6 99.9%NEW 1GB RAM+16GB ROM 1810mAh Sin...      65906.0  iPhone 6
# 14  Iphone 6 - 4.7" - 1/64GB - 8Mpx - 4G (Recondit...      77500.0  iPhone 6
# 22  Apple iPhone 6 Renewed 99.9%New 32G Unlocked F...      73305.0  iPhone 6
# 37  IPhone 6 99.9%NEW 1GB RAM+32GB ROM 1810mAh Sin...      68898.0  iPhone 6
# 40  Apple IPhone 6 99.9%NEW 1GB RAM+16GB ROM 1810m...      57949.0  iPhone 6

# %%
# Filter df1 to include only rows where the Series is "iPhone 16" after cleaning and price filtering
iphone_16 = df1[df1['Series'] == 'iPhone 16']

# Display the filtered DataFrame to see all iPhone 16 records
print(iphone_16)
# Out:
#                                        Phone_info  Phone_Price     Series
# 2  Apple IPhone 16 - 8GB-256GB - 5G - Ultramarine    1899000.0  iPhone 16

# %%
# Display the first 5 rows of the updated DataFrame to get a quick overview
df1.head(5)
# Out:
#                                           Phone_info  Phone_Price  \
# 0  Apple IPhone 11 6.1-Inch Liquid Retina LCD (4G...     500000.0
# 1  Apple IPhone 12 Pro Max - 6.7-Inch - 128GB ROM...     690000.0
# 2     Apple IPhone 16 - 8GB-256GB - 5G - Ultramarine    1899000.0
# 3  IPhone 6 99.9%NEW 1GB RAM+16GB ROM 1810mAh Sin...      65906.0
# 4  Apple IPhone 6s Plus 99.9%NEW 2GB RAM+32GB ROM...      88907.0
#
#               Series
# 0          iPhone 11
# 1  iPhone 12 Pro Max
# 2          iPhone 16
# 3           iPhone 6
# 4     iPhone 6s Plus

# %% [markdown]
# ### Saving the cleaned DataFrame to a CSV file

# %%
# Save the cleaned and filtered DataFrame to a CSV file named 'cleaned_jumia_iphone.csv'
# index=False ensures that the row indices are not written to the file
#df1.to_csv('cleaned_jumia_iphone.csv', index=False)
